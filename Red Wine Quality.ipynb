# %% [markdown]
# # Red Wine Quality Analysis

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load dataset

# %%
df = pd.read_csv('winequality-red.csv')

# %% [markdown]
# ## Data Exploration & Cleaning

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
# Number of rows & columns
print(f'The dataset has {df.shape[0]} rows')
print(f'The dataset has {df.shape[1]} columns')
# Out:
# The dataset has 1599 rows
# The dataset has 12 columns

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.info(show_counts = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 13 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Fixed_Acidity         float64
#  1   Volatile_Acidity      float64
#  2   Citric_Acid           float64
#  3   Residual_Sugar        float64
#  4   Chlorides             float64
#  5   Free_Sulfur_Dioxide   float64
#  6   Total_Sulfur_Dioxide  float64
#  7   Density               float64
#  8   pH                    float64
#  9   Sulphates             float64
#  10  Alcohol               float64
#  11  Quality               int64
#  12  Reviews               object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 162.5+ KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# ## Checking for missing  values

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# Rename columns for easier reference
df.rename(columns={
    'fixed acidity': 'Fixed_Acidity', 'volatile acidity': 'Volatile_Acidity',
    'citric acid': 'Citric_Acid', 'residual sugar': 'Residual_Sugar',
    'chlorides': 'Chlorides', 'free sulfur dioxide': 'Free_Sulfur_Dioxide',
    'total sulfur dioxide': 'Total_Sulfur_Dioxide', 'density': 'Density', 'pH': 'pH', 
    'sulphates': 'Sulphates', 'alcohol': 'Alcohol', 'quality': 'Quality'}, inplace = True)

# %%
df.head()
# Out:
#    Fixed_Acidity  Volatile_Acidity  Citric_Acid  Residual_Sugar  Chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    Free_Sulfur_Dioxide  Total_Sulfur_Dioxide  Density    pH  Sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    Alcohol  Quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ### Analyzing column 'Quality'

# %%
df ['Quality']
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: Quality, Length: 1599, dtype: int64

# %%
df ['Quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: Quality, dtype: int64

# %% [markdown]
# ## Adding column 'Reviews'
# - It will make the visibility in good and bad by quality

# %%
reviews = []
for i in df['Quality']:
    if i >= 3 and i <= 5:
        reviews.append('Bad')
    elif i >= 6 and i <= 8:
        reviews.append('Good')
df['Reviews'] = reviews

# %% [markdown]
# - Applying condition to make the difference visible
# - If quality is greater than equal to 3 and less than equal to 5, it will consider it "Bad"
# - If quality is greater than equal to 6 and less than equal to 8, it will consider it "Good"

# %%
df.head(10)
# Out:
#    Fixed_Acidity  Volatile_Acidity  Citric_Acid  Residual_Sugar  Chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    Free_Sulfur_Dioxide  Total_Sulfur_Dioxide  Density    pH  Sulphates  \
# ...

# %%
df ['Reviews'].value_counts()
# Out:
# Good    855
# Bad     744
# Name: Reviews, dtype: int64

# %%
sns.barplot(x = 'Reviews', y = 'Quality', data = df)

plt.title('Wine Quality by Reviews', fontsize = 14)
plt.xlabel('Quality', fontsize = 12)
plt.ylabel('Reviews', fontsize = 12)
plt.show()

# %% [markdown]
# - The differnce is completely visible
# - The majority reviews are Good!

# %% [markdown]
# ## Min, Max, Avg of Quality by Ingredients

# %% [markdown]
# ### Avg, Max, Min of quality by 'Fixed Acidity'

# %%
avg_wine_quality = df.groupby('Quality')['Fixed_Acidity'].mean()

highest_fixed_acidity = avg_wine_quality.max()
lowest_fixed_acidity = avg_wine_quality.min()

print(f"Highest Fixed Acidity : {highest_fixed_acidity}")
print(f"Lowest Fixed Acidity : {lowest_fixed_acidity}")
# Out:
# Highest Fixed Acidity : 8.872361809045225
# Lowest Fixed Acidity : 7.779245283018868

# %%
avg_wine_quality = df.groupby('Quality')['Fixed_Acidity'].mean()
avg_wine_quality
# Out:
# Quality
# 3    8.360000
# 4    7.779245
# 5    8.167254
# 6    8.347179
# 7    8.872362
# 8    8.566667
# Name: Fixed_Acidity, dtype: float64

# %% [markdown]
# - Rechecking of mean, if its right or wrong

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x = 'Quality', y = 'Fixed_Acidity', data = df)
plt.title('Wine Quality by Fixed_Acidity', fontsize = 14)
plt.xlabel('Quality', fontsize = 12)
plt.ylabel('Avg Fixed_Acidity', fontsize = 12)
plt.show()

# %% [markdown]
# ### Avg, Max, Min of quality by 'Volatile Acidity'

# %%
avg_wine_quality = df.groupby('Quality')['Volatile_Acidity'].mean()

highest_volatile_acidity = avg_wine_quality.max()
lowest_volatile_acidity = avg_wine_quality.min()

print(f"Highest Volatile Acidity : {highest_volatile_acidity}")
print(f"Lowest Volatile Acidity : {lowest_volatile_acidity}")
# Out:
# Highest Volatile Acidity : 0.8845000000000001
# Lowest Volatile Acidity : 0.40391959798994975

# %%
avg_wine_quality = df.groupby('Quality')['Volatile_Acidity'].mean()
avg_wine_quality
# Out:
# Quality
# 3    0.884500
# 4    0.693962
# 5    0.577041
# 6    0.497484
# 7    0.403920
# 8    0.423333
# Name: Volatile_Acidity, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x = 'Quality', y = 'Volatile_Acidity', data = df)
plt.title('Wine Quality by Volatile_Acidity', fontsize = 14)
plt.xlabel('Quality', fontsize = 12)
plt.ylabel('Avg Volatile_Acidity', fontsize = 12)
plt.show()

# %% [markdown]
# ### Avg, Max, Min of quality by 'Citric Acid'

# %%
avg_wine_quality = df.groupby('Quality')['Citric_Acid'].mean()

highest_citric_acid = avg_wine_quality.max()
lowest_citric_acid = avg_wine_quality.min()

print(f"Highest Citric_Acid : {highest_citric_acid}")
print(f"Lowest Citric_Acid : {lowest_citric_acid}")
# Out:
# Highest Citric_Acid : 0.39111111111111113
# Lowest Citric_Acid : 0.17099999999999999

# %%
avg_wine_quality = df.groupby('Quality')['Citric_Acid'].mean()
avg_wine_quality
# Out:
# Quality
# 3    0.171000
# 4    0.174151
# 5    0.243686
# 6    0.273824
# 7    0.375176
# 8    0.391111
# Name: Citric_Acid, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x = 'Quality', y = 'Citric_Acid', data = df)
plt.title('Wine Quality by Citric_Acid', fontsize = 14)
plt.xlabel('Quality', fontsize = 12)
plt.ylabel('Avg Citric_Acid', fontsize = 12)
plt.show()

# %% [markdown]
# ### Avg, Max, Min of quality by 'Residual Sugar'

# %%
avg_wine_quality = df.groupby('Quality')['Residual_Sugar'].mean()

highest_sugar_level = avg_wine_quality.max()
lowest_sugar_level = avg_wine_quality.min()

print(f"Highest Residual_Sugar : {highest_sugar_level}")
print(f"Lowest Residual_Sugar : {lowest_sugar_level}")
# Out:
# Highest Residual_Sugar : 2.7206030150753766
# Lowest Residual_Sugar : 2.477194357366771

# %%
avg_wine_quality = df.groupby('Quality')['Residual_Sugar'].mean()
avg_wine_quality
# Out:
# Quality
# 3    2.635000
# 4    2.694340
# 5    2.528855
# 6    2.477194
# 7    2.720603
# 8    2.577778
# Name: Residual_Sugar, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x = 'Quality', y = 'Residual_Sugar', data = df)
plt.title('Wine Quality by Residual Sugar', fontsize = 14)
plt.xlabel('Quality', fontsize = 12)
plt.ylabel('Avg sugar level', fontsize = 12)
plt.show()

# %% [markdown]
# ### Avg, Max, Min of quality by 'Chlorides'

# %%
avg_wine_quality = df.groupby('Quality')['Chlorides'].mean()

highest_chlorides = avg_wine_quality.max()
lowest_chlorides = avg_wine_quality.min()

print(f"Highest Chlorides : {highest_chlorides}")
print(f"Lowest Chlorides : {lowest_chlorides}")
# Out:
# Highest Chlorides : 0.12249999999999997
# Lowest Chlorides : 0.06844444444444445

# %%
avg_wine_quality = df.groupby('Quality')['Chlorides'].mean()
avg_wine_quality
# Out:
# Quality
# 3    0.122500
# 4    0.090679
# 5    0.092736
# 6    0.084956
# 7    0.076588
# 8    0.068444
# Name: Chlorides, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x = 'Quality', y = 'Chlorides', data = df)
plt.title('Wine Quality by Chlorides', fontsize = 14)
plt.xlabel('Quality', fontsize = 12)
plt.ylabel('Avg Chlorides Rate', fontsize = 12)
plt.show()

# %% [markdown]
# ### Avg, Max, Min of quality by 'Free Sulfur Dioxide'

# %%
avg_wine_quality = df.groupby('Quality')['Free_Sulfur_Dioxide'].mean()

highest_free_sulpur_dioxide = avg_wine_quality.max()
lowest_free_sulpur_dioxide = avg_wine_quality.min()

print(f"Highest Free_Sulpur_Dioxide : {highest_free_sulpur_dioxide}")
print(f"Lowest Free_Sulpur_Dioxide : {lowest_free_sulpur_dioxide}")
# Out:
# Highest Free_Sulpur_Dioxide : 16.983847283406753
# Lowest Free_Sulpur_Dioxide : 11.0

# %%
avg_wine_quality = df.groupby('Quality')['Free_Sulfur_Dioxide'].mean()
avg_wine_quality
# Out:
# Quality
# 3    11.000000
# 4    12.264151
# 5    16.983847
# 6    15.711599
# 7    14.045226
# 8    13.277778
# Name: Free_Sulfur_Dioxide, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x = 'Quality', y = 'pH', data = df)
plt.title('Wine Quality by Free_Sulfur_Dioxide', fontsize = 14)
plt.xlabel('Quality', fontsize = 12)
plt.ylabel('Avg Free Sulfur Dioxide', fontsize = 12)
plt.show()

# %% [markdown]
# ### Avg, Max, Min of quality by 'Total Sulfur Dioxide'

# %%
avg_wine_quality = df.groupby('Quality')['Total_Sulfur_Dioxide'].mean()

highest_total_sulfur_dioxide = avg_wine_quality.max()
lowest_total_sulfur_dioxide = avg_wine_quality.min()

print(f"Highest Total_Sulfur_Dioxide : {highest_total_sulfur_dioxide}")
print(f"Lowest Total_Sulfur_Dioxide : {lowest_total_sulfur_dioxide}")
# Out:
# Highest Total_Sulfur_Dioxide : 56.51395007342144
# Lowest Total_Sulfur_Dioxide : 24.9

# %%
avg_wine_quality = df.groupby('Quality')['Total_Sulfur_Dioxide'].mean()
avg_wine_quality
# Out:
# Quality
# 3    24.900000
# 4    36.245283
# 5    56.513950
# 6    40.869906
# 7    35.020101
# 8    33.444444
# Name: Total_Sulfur_Dioxide, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x = 'Quality', y = 'Total_Sulfur_Dioxide', data = df)
plt.title('Wine Quality by Total_Sulfur_Dioxide', fontsize = 14)
plt.xlabel('Quality', fontsize = 12)
plt.ylabel('Avg Total_Sulfur_Dioxide', fontsize = 12)
plt.show()

# %% [markdown]
# ### Avg, Max, Min of quality by 'Density'

# %%
avg_wine_quality = df.groupby('Quality')['Density'].mean()

highest_Density = avg_wine_quality.max()
lowest_Density = avg_wine_quality.min()

print(f"Highest Density : {highest_Density}")
print(f"Lowest Density : {lowest_Density}")
# Out:
# Highest Density : 0.9974639999999999
# Lowest Density : 0.9952122222222223

# %%
avg_wine_quality = df.groupby('Quality')['Density'].mean()
avg_wine_quality
# Out:
# Quality
# 3    0.997464
# 4    0.996542
# 5    0.997104
# 6    0.996615
# 7    0.996104
# 8    0.995212
# Name: Density, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x = 'Quality', y = 'Density', data = df)
plt.title('Wine Quality by Density', fontsize = 14)
plt.xlabel('Quality', fontsize = 12)
plt.ylabel('Avg Density', fontsize = 12)
plt.show()

# %% [markdown]
# ### Avg, Max, Min of quality by 'pH'

# %%
avg_wine_quality = df.groupby('Quality')['pH'].mean()

highest_pH_value = avg_wine_quality.max()
lowest_pH_value = avg_wine_quality.min()

print(f"Highest pH Value : {highest_pH_value}")
print(f"Lowest pH Value : {lowest_pH_value}")
# Out:
# Highest pH Value : 3.3979999999999997
# Lowest pH Value : 3.2672222222222222

# %%
avg_wine_quality = df.groupby('Quality')['pH'].mean()
avg_wine_quality
# Out:
# Quality
# 3    3.398000
# 4    3.381509
# 5    3.304949
# 6    3.318072
# 7    3.290754
# 8    3.267222
# Name: pH, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x = 'Quality', y = 'pH', data = df)
plt.title('Wine Quality by pH', fontsize = 14)
plt.xlabel('Quality', fontsize = 12)
plt.ylabel('Avg pH Value', fontsize = 12)
plt.show()

# %% [markdown]
# ### Avg, Max, Min of quality by 'Sulphates'

# %%
avg_wine_quality = df.groupby('Quality')['Sulphates'].mean()

highest_Sulphates = avg_wine_quality.max()
lowest_Sulphates = avg_wine_quality.min()

print(f"Highest Sulphates : {highest_Sulphates}")
print(f"Lowest Sulphates : {lowest_Sulphates}")
# Out:
# Highest Sulphates : 0.7677777777777778
# Lowest Sulphates : 0.5700000000000001

# %%
avg_wine_quality = df.groupby('Quality')['Sulphates'].mean()
avg_wine_quality
# Out:
# Quality
# 3    0.570000
# 4    0.596415
# 5    0.620969
# 6    0.675329
# 7    0.741256
# 8    0.767778
# Name: Sulphates, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x = 'Quality', y = 'Sulphates', data = df)
plt.title('Wine Quality by Sulphates', fontsize = 14)
plt.xlabel('Quality', fontsize = 12)
plt.ylabel('Avg Sulphates', fontsize = 12)
plt.show()

# %% [markdown]
# ### Avg, Max, Min of quality by 'Alcohol'

# %%
avg_wine_quality = df.groupby('Quality')['Alcohol'].mean()

highest_alcohol_Count = avg_wine_quality.max()
lowest_alcohol_Count = avg_wine_quality.min()

print(f"Highest Alcohol Level : {highest_alcohol_Count}")
print(f"Lowest Alcohol Level : {lowest_alcohol_Count}")
# Out:
# Highest Alcohol Level : 12.094444444444443
# Lowest Alcohol Level : 9.899706314243758

# %%
avg_wine_quality = df.groupby('Quality')['Alcohol'].mean()
avg_wine_quality
# Out:
# Quality
# 3     9.955000
# 4    10.265094
# 5     9.899706
# 6    10.629519
# 7    11.465913
# 8    12.094444
# Name: Alcohol, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x = 'Quality', y = 'Alcohol', data = df)
plt.title('Wine Quality by Alcohol', fontsize = 14)
plt.xlabel('Quality', fontsize = 12)
plt.ylabel('Avg Alcohol Level', fontsize = 12)
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %%
df.hist(bins = 30, figsize = (12, 9))
plt.subplots_adjust(hspace = 0.5)
